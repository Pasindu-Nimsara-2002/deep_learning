# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image using OpenCV
image = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)

# Normalize the image to [0, 255] range manually
normalized_image = cv2.normalize(image, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)

# Display the normalized image using Matplotlib
plt.imshow(normalized_image, cmap='gray')
plt.title('Normalized Image')
plt.axis('off')  # Hide axis
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image using OpenCV
image = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)

# Normalize the image to the range [0, 1]
normalized_image_01 = cv2.normalize(image, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)

# Display the normalized image using Matplotlib
plt.imshow(normalized_image_01, cmap='gray')
plt.title('Normalized Image [0, 1]')
plt.axis('off')  # Hide axis
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image using OpenCV
image = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)

# Normalize the image using L2 norm (scaled to [0, 255])
normalized_image_l2 = cv2.normalize(image, None, alpha=0, beta=255, norm_type=cv2.NORM_L2)

# Display the normalized image using Matplotlib
plt.imshow(normalized_image_l2, cmap='gray')
plt.title('Normalized Image L2')
plt.axis('off')  # Hide axis
plt.show()

# %%
import cv2
import numpy as np

# Read the image in grayscale
img = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)

# Calculate the mean value of the image
mean_value = np.mean(img)

# Normalize the image around 127
normalized_img = img - mean_value + 127

# Clip the values to stay within the valid pixel range (0 to 255)
normalized_img = np.clip(normalized_img, 0, 255).astype(np.uint8)

# plt.imshow(normalized_img, cmap='gray')
# plt.title('Normalized Image L2')
# plt.axis('off')  # Hide axis
# plt.show()

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
# plt.imshow(image, cmap='inferno')  # Use a thermal colormap
plt.imshow(normalized_img, cmap='gray')
plt.axis("off")
plt.title("Thermal Image")

# Compute histogram
hist = cv2.calcHist([normalized_img], [0], None, [256], [0, 256])

# Plot histogram
plt.subplot(1, 2, 2)
plt.title("Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.plot(hist, color='black')
plt.xlim([0, 256])

plt.show()

# %%
import cv2
import numpy as np

# Read the image in grayscale
img = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)

# Calculate the mean value of the image
mean_value = np.mean(img)

# Normalize the image around 127
normalized_img = img - mean_value + 127

# Clip the values to stay within the valid pixel range (0 to 255)
normalized_img = np.clip(normalized_img, 0, 255).astype(np.uint8)

# Apply histogram equalization
equalized = cv2.equalizeHist(img)
equalized_normalized_img = cv2.equalizeHist(normalized_img)

# Compute histogram
hist_1 = cv2.calcHist([img], [0], None, [256], [0, 256])
hist_2 = cv2.calcHist([normalized_img], [0], None, [256], [0, 256])
hist_3 = cv2.calcHist([equalized], [0], None, [256], [0, 256])
hist_4 = cv2.calcHist([equalized_normalized_img], [0], None, [256], [0, 256])

# Plot original and enhanced images

plt.figure(figsize=(20, 10))
plt.subplot(2, 4, 1)
# plt.imshow(image, cmap='inferno')  # Use a thermal colormap
plt.imshow(img, cmap='gray')
plt.axis("off")
plt.title("Original Image")

plt.subplot(2, 4, 2)
plt.imshow(normalized_img, cmap='gray')
plt.axis("off")
plt.title("Normalized Thermal Image")

plt.subplot(2, 4, 3)
plt.imshow(equalized, cmap='gray')
plt.axis("off")
plt.title("Original Equalized Thermal Image")

plt.subplot(2, 4, 4)
plt.imshow(equalized_normalized_img, cmap='gray')
plt.axis("off")
plt.title("Equalized Normalized Image")

# Plot histogram

plt.subplot(2, 4, 5)
plt.title("Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.plot(hist_1, color='black')
plt.xlim([0, 256])

plt.subplot(2, 4, 6)
plt.title("Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.plot(hist_2, color='black')
plt.xlim([0, 256])

plt.subplot(2, 4, 7)
plt.title("Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.plot(hist_3, color='black')
plt.xlim([0, 256])

plt.subplot(2, 4, 8)
plt.title("Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.plot(hist_4, color='black')
plt.xlim([0, 256])

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image using OpenCV
image = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)

# Calculate the mean value of the image
mean_value = np.mean(image)

# Normalize the image around 127
normalized_img = image - mean_value + 127

# Clip the values to stay within the valid pixel range (0 to 255)
normalized_img = np.clip(normalized_img, 0, 255).astype(np.uint8)

# Normalize the image to [0, 255] range manually
normalized_image = cv2.normalize(normalized_img, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)

# Normalize the image to the range [0, 1]
normalized_image_01 = cv2.normalize(normalized_img, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)

# Normalize the image using L2 norm (scaled to [0, 255])
normalized_image_l2 = cv2.normalize(normalized_img, None, alpha=0, beta=255, norm_type=cv2.NORM_L2)

hist_4 = cv2.calcHist([normalized_image], [0], None, [256], [0, 256])


# Display the normalized image using Matplotlib

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(normalized_image, cmap='gray')
plt.title('Normalized Image [0, 1]')
plt.axis('off')  # Hide axis

plt.subplot(1, 2, 2)
plt.title("Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.plot(hist_4, color='black')
plt.xlim([0, 256])

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image using OpenCV
image = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)

# # Calculate the mean value of the image
# mean_value = np.mean(image)

# # Normalize the image around 127
# normalized_img = image - mean_value + 127

# # Clip the values to stay within the valid pixel range (0 to 255)
# normalized_img = np.clip(normalized_img, 0, 255).astype(np.uint8)

equalized = cv2.equalizeHist(image)

# # Normalize the image to [0, 255] range manually
normalized_image = cv2.normalize(equalized, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)

# # Normalize the image to the range [0, 1]
# normalized_image_01 = cv2.normalize(equalized, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)

# Normalize the image using L2 norm (scaled to [0, 255])
# normalized_image_l2 = cv2.normalize(image, None, alpha=0, beta=255, norm_type=cv2.NORM_L2)

hist_4 = cv2.calcHist([normalized_image], [0], None, [256], [0, 256])


# Display the normalized image using Matplotlib

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(normalized_image, cmap='gray')
plt.title('Normalized Image [0, 1]')
plt.axis('off')  # Hide axis

plt.subplot(1, 2, 2)
plt.title("Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.plot(hist_4, color='black')
plt.xlim([0, 256])

plt.show()

# %% [markdown]
# Canny Edge Detector with Track Bar

# %%
import cv2
import numpy as np

def on_trackbar(val):
    pass

def main():
    # Load an image
    img = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)
    equalized = cv2.equalizeHist(img)
    
    if img is None:
        print("Error: Could not load image.")
        return
    
    # Resize the image to a smaller size
    equalized = cv2.resize(equalized, (800, 600))
    
    # Create a window
    cv2.namedWindow('Canny Edge Detector', cv2.WINDOW_NORMAL)
    cv2.resizeWindow('Canny Edge Detector', 800, 600)
    
    # Create trackbars for lower and upper thresholds
    cv2.createTrackbar('Lower Threshold', 'Canny Edge Detector', 50, 255, on_trackbar)
    cv2.createTrackbar('Upper Threshold', 'Canny Edge Detector', 150, 255, on_trackbar)
    
    while True:
        # Get the current trackbar positions
        lower = cv2.getTrackbarPos('Lower Threshold', 'Canny Edge Detector')
        upper = cv2.getTrackbarPos('Upper Threshold', 'Canny Edge Detector')
        
        # Apply Canny edge detection
        edges = cv2.Canny(equalized, lower, upper)
        
        # Show the result
        cv2.imshow('Canny Edge Detector', edges)
        
        # Press 'q' to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# QObject::moveToThread: Current thread (0x71a1c00) is not the object's thread (0x780d550).
# Cannot move to target thread (0x71a1c00)
#
# QObject::moveToThread: Current thread (0x71a1c00) is not the object's thread (0x780d550).
# Cannot move to target thread (0x71a1c00)
#
# QObject::moveToThread: Current thread (0x71a1c00) is not the object's thread (0x780d550).
# Cannot move to target thread (0x71a1c00)
#
# QObject::moveToThread: Current thread (0x71a1c00) is not the object's thread (0x780d550).
# Cannot move to target thread (0x71a1c00)
#
# QObject::moveToThread: Current thread (0x71a1c00) is not the object's thread (0x780d550).
# Cannot move to target thread (0x71a1c00)
#
# QObject::moveToThread: Current thread (0x71a1c00) is not the object's thread (0x780d550).
# Cannot move to target thread (0x71a1c00)
#
# QObject::moveToThread: Current thread (0x71a1c00) is not the object's thread (0x780d550).
# Cannot move to target thread (0x71a1c00)
#
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image using OpenCV
image = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)
equalized = cv2.equalizeHist(image)

# Apply a Gaussian blur (low-pass filter)
low_pass_image = cv2.GaussianBlur(equalized, (299, 299), 0)

# Subtract the low-pass filtered image from the original to get the high-pass filtered image
high_pass_image = cv2.subtract(equalized, low_pass_image)

# end = cv2.add(equalized, otsu_thresh_img)
# end = cv2.add(end, otsu_thresh_img)
# end = cv2.add(end, otsu_thresh_img)
# end = cv2.add(end, high_pass_image)

# Step 2: Noise Removal (Denoising)
# denoised = cv2.GaussianBlur(end, (25, 25), 0)  # Gaussian Blur for smoothing
# denoised_img = cv2.medianBlur(high_pass_image, 15)
# new = cv2.equalizeHist(end)
# Normalize the image to the range [0, 1]
# normalized_image_01 = cv2.normalize(high_pass_image, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)

# Apply adaptive thresholding
# adaptive_thresh_img = cv2.adaptiveThreshold(high_pass_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, 
#                                            cv2.THRESH_BINARY, 11, 2)

# _, otsu_thresh_img = cv2.threshold(high_pass_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply global thresholding (e.g., threshold value = 127)
_, thresholded_img = cv2.threshold(high_pass_image, 30, 40, cv2.THRESH_BINARY)

end = cv2.add(equalized, high_pass_image)
end = cv2.add(end, high_pass_image)
end = cv2.add(end, high_pass_image)

end2 = cv2.add(image, high_pass_image)
end2 = cv2.add(end2, high_pass_image)
end2 = cv2.add(end2, high_pass_image) 


high = cv2.medianBlur(high_pass_image, 25)
high2 = cv2.add(high_pass_image, high_pass_image)
high3 = cv2.add(high, high_pass_image)

final = cv2.GaussianBlur(end, (45, 45), 0)
final2 = cv2.add(equalized, high)

_, mask = cv2.threshold(image, 20, 255, cv2.THRESH_BINARY)
inpainted_image = cv2.inpaint(end, mask, inpaintRadius=3, flags=cv2.INPAINT_TELEA)

denoised_image = cv2.medianBlur(end, 25)

# Display the original, low-pass, and high-pass filtered images using Matplotlib
fig, axes = plt.subplots(3, 2, figsize=(20, 20))

# Original Image
axes[0][0].imshow(equalized, cmap='gray')
axes[0][0].set_title('Original Image')
axes[0][0].axis('off')

# Low-pass filtered Image
# High-pass filtered Image
axes[0][1].imshow(high_pass_image, cmap='gray')
axes[0][1].set_title('High-pass Filtered Image')
axes[0][1].axis('off')

# High-pass + Image
axes[1][0].imshow(end, cmap='gray')
axes[1][0].set_title('High-pass*3 + equalized Image')
axes[1][0].axis('off')

axes[1][1].imshow(high, cmap='gray')
axes[1][1].set_title('High pass with median blur')
axes[1][1].axis('off')

axes[2][0].imshow(final2, cmap='gray')
axes[2][0].set_title('High-pass*3 + GaussianBlured + equalized Image')
axes[2][0].axis('off')

axes[2][1].imshow(end2, cmap='gray')
axes[2][1].set_title('High-pass*3 + original Image')
axes[2][1].axis('off')

plt.show()

# %%
# Create a mask where white patches are 255, rest 0
# _, mask = cv2.threshold(high, 5, 255, cv2.THRESH_BINARY)  # Adjust threshold as needed
# Dilate the mask a bit to cover the edges of the patches
ret, th = cv2.threshold(high_pass_image, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

kernel = np.ones((3,3),np.uint8)

mask1 = cv2.dilate(th, kernel, iterations = 5)
mask2 = cv2.erode(th,kernel,iterations = 3)


# normalized_img = mask2 - 127
# normalized_img = np.clip(normalized_img, 0, 255).astype(np.uint8)

height, width= image.shape  # Get height, width, and number of channels (discarded)
new_image = np.full((height, width), 127, dtype=np.uint8) 
mask2 = cv2.subtract(mask2, new_image)

# Inpaint the image
inpainted_img = cv2.inpaint(image, mask, inpaintRadius=3, flags=cv2.INPAINT_TELEA) # or cv2.INPAINT_NS


# Display the original, low-pass, and high-pass filtered images using Matplotlib
fig, axes = plt.subplots(2, 2, figsize=(20, 20))

axes[0][0].imshow(mask1, cmap='gray')
axes[0][0].set_title('Mask Image')
axes[0][0].axis('off')

axes[0][1].imshow(mask2, cmap='gray')
axes[0][1].set_title('High-pass Filterwith Median Blur')
axes[0][1].axis('off')

axes[1][0].imshow(inpainted_img, cmap='gray')
axes[1][0].set_title('Inpainted Image')
axes[1][0].axis('off')

axes[1][1].imshow(th, cmap='gray')
axes[1][1].set_title('Inpainted Image')
axes[1][1].axis('off')
# Out:
# (-0.5, 1734.5, 1292.5, -0.5)

# %%
corners = cv2.goodFeaturesToTrack(final2, maxCorners=500, qualityLevel=0.01, minDistance=10)
image_color = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

for corner in np.int0(corners):
    x, y = corner.ravel()
    cv2.circle(image_color, (x, y), 3, (0, 255, 0), -1)


plt.figure(figsize=(20, 10))
plt.imshow(image_color, cmap='gray')
plt.show()
# Out:
# /tmp/ipykernel_6648/2301495820.py:4: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   for corner in np.int0(corners):

# %%
sift = cv2.SIFT_create()
keypoints, descriptors = sift.detectAndCompute(final2, None)

image_with_keypoints = cv2.drawKeypoints(image, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.figure(figsize=(20, 10))
plt.imshow(image_with_keypoints, cmap='gray')
plt.show()
