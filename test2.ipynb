# %%
import cv2
import matplotlib.pyplot as plt

# Read the thermal image (assuming it's grayscale)
image = cv2.imread("./image.png", cv2.IMREAD_GRAYSCALE)

# Plot the original thermal image
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
# plt.imshow(image, cmap='inferno')  # Use a thermal colormap
plt.imshow(image, cmap='gray')
plt.axis("off")
plt.title("Thermal Image")

# Compute histogram
hist = cv2.calcHist([image], [0], None, [256], [0, 256])

# Plot histogram
plt.subplot(1, 2, 2)
plt.title("Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.plot(hist, color='black')
plt.xlim([0, 256])

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the thermal image (assuming it's grayscale)
image = cv2.imread("./image.png", cv2.IMREAD_GRAYSCALE)
equalized_image = cv2.equalizeHist(image)
t = np.arange(255, -1, -1, dtype=np.uint8)
i_image  = cv2.LUT(image,t)

# Plot the original thermal image
plt.figure(figsize=(15, 10))
plt.subplot(1, 3, 1)
# plt.imshow(image, cmap='inferno')  # Use a thermal colormap
plt.imshow(image, cmap='gray')
plt.axis("off")
plt.title("Thermal Image")

# Plot the original thermal image
plt.subplot(1, 3, 2)
plt.imshow(i_image, cmap='gray')
plt.axis("off")
plt.title("Equalized thermal Image")

# Compute histogram
hist = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])

# Plot histogram
plt.subplot(1, 3, 3)
plt.title("Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.plot(hist, color='black')
plt.xlim([0, 256])

plt.show()

# %%
def auto_canny_thresholds(image, sigma=0.33):
    median_val = np.median(image)  # Compute median intensity
    print(median_val)
    lower = int(max(0, (1.0 - sigma) * median_val))  # Lower threshold
    upper = int(min(255, (1.0 + sigma) * median_val))  # Upper threshold
    return lower, upper

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)
# image = cv2.equalizeHist(image)
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
image_ = clahe.apply(image)


# Apply Gaussian blur to reduce noise and improve edge detection
blurred_image = cv2.GaussianBlur(image_, (5, 5), 0)

low_thresh, high_thresh = auto_canny_thresholds(blurred_image)

# Apply Canny edge detector
edges = cv2.Canny(blurred_image, 20, 35)

# Plot the original and edge-detected images
plt.figure(figsize=(10, 10))

# Original image
plt.subplot(2, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Edge-detected image
plt.subplot(2, 2, 2)
plt.imshow(edges, cmap='gray')
plt.title('Canny Edge Detection')
plt.axis('off')

# Original image
plt.subplot(2, 2, 3)
plt.imshow(blurred_image, cmap='gray')
plt.title('Blurred Image')
plt.axis('off')

# Edge-detected image
plt.subplot(2, 2, 4)
plt.imshow(edges, cmap='gray')
plt.title('Canny Edge Detection')
plt.axis('off')

plt.show()
# Out:
# 91.0

# %%
np.median(grad_magnitude)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 np.median(grad_magnitude)
#
# NameError: name 'grad_magnitude' is not defined

# %%
import numpy as np

arr = np.array([[1, 3, 5], 
                [2, 4, 6]])

median_value = np.median(arr)
print(median_value)
# Out:
# 3.5

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image in grayscale
image = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)

# Apply adaptive thresholding
adaptive = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                 cv2.THRESH_BINARY, 21, 10)

# Create a figure
plt.figure(figsize=(10, 5))

# Plot the original thermal image
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')  # Change 'gray' to 'inferno' if thermal visualization is needed
plt.axis("off")
plt.title("Original Thermal Image")

# Plot the adaptive thresholded image
plt.subplot(1, 2, 2)
plt.imshow(adaptive, cmap='gray')
plt.axis("off")
plt.title("Adaptive Thresholding")

# Show the images
plt.show()
cv2.imshow("Adaptive Threshold", adaptive)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2cb2b9e0) is not the object's thread (0x304407a0).
# Cannot move to target thread (0x2cb2b9e0)
#
# QObject::moveToThread: Current thread (0x2cb2b9e0) is not the object's thread (0x304407a0).
# Cannot move to target thread (0x2cb2b9e0)
#
# QObject::moveToThread: Current thread (0x2cb2b9e0) is not the object's thread (0x304407a0).
# Cannot move to target thread (0x2cb2b9e0)
#
# QObject::moveToThread: Current thread (0x2cb2b9e0) is not the object's thread (0x304407a0).
# Cannot move to target thread (0x2cb2b9e0)
#
# QObject::moveToThread: Current thread (0x2cb2b9e0) is not the object's thread (0x304407a0).
# Cannot move to target thread (0x2cb2b9e0)
#
# QObject::moveToThread: Current thread (0x2cb2b9e0) is not the object's thread (0x304407a0).
# Cannot move to target thread (0x2cb2b9e0)
#
# QObject::moveToThread: Current thread (0x2cb2b9e0) is not the object's thread (0x304407a0).
# Cannot move to target thread (0x2cb2b9e0)
#
# ...

# %%
import cv2
import numpy as np

def on_trackbar(val):
    pass

def main():
    # Load an image
    img = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)
    
    if img is None:
        print("Error: Could not load image.")
        return
    
    # Resize the image to a smaller size
    img = cv2.resize(img, (400, 300))
    
    # Create a window
    cv2.namedWindow('Canny Edge Detector', cv2.WINDOW_NORMAL)
    cv2.resizeWindow('Canny Edge Detector', 400, 300)
    
    # Create trackbars for lower and upper thresholds
    cv2.createTrackbar('Lower Threshold', 'Canny Edge Detector', 50, 255, on_trackbar)
    cv2.createTrackbar('Upper Threshold', 'Canny Edge Detector', 150, 255, on_trackbar)
    
    while True:
        # Get the current trackbar positions
        lower = cv2.getTrackbarPos('Lower Threshold', 'Canny Edge Detector')
        upper = cv2.getTrackbarPos('Upper Threshold', 'Canny Edge Detector')
        
        # Apply Canny edge detection
        edges = cv2.Canny(img, lower, upper)
        
        # Show the result
        cv2.imshow('Canny Edge Detector', edges)
        
        # Press 'q' to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# QObject::moveToThread: Current thread (0x39bcfc20) is not the object's thread (0x39f7e6d0).
# Cannot move to target thread (0x39bcfc20)
#
# QObject::moveToThread: Current thread (0x39bcfc20) is not the object's thread (0x39f7e6d0).
# Cannot move to target thread (0x39bcfc20)
#
# QObject::moveToThread: Current thread (0x39bcfc20) is not the object's thread (0x39f7e6d0).
# Cannot move to target thread (0x39bcfc20)
#
# QObject::moveToThread: Current thread (0x39bcfc20) is not the object's thread (0x39f7e6d0).
# Cannot move to target thread (0x39bcfc20)
#
# QObject::moveToThread: Current thread (0x39bcfc20) is not the object's thread (0x39f7e6d0).
# Cannot move to target thread (0x39bcfc20)
#
# QObject::moveToThread: Current thread (0x39bcfc20) is not the object's thread (0x39f7e6d0).
# Cannot move to target thread (0x39bcfc20)
#
# QObject::moveToThread: Current thread (0x39bcfc20) is not the object's thread (0x39f7e6d0).
# Cannot move to target thread (0x39bcfc20)
#
# ...
